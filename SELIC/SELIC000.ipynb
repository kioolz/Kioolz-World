# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import seaborn as sns; sns.set()

#Obtendo dados da Base central do Banco do Brasil
def consulta_bc(codigo_bcb):
  url = 'http://api.bcb.gov.br/dados/serie/bcdata.sgs.{}/dados?formato=json'.format(codigo_bcb)
  df = pd.read_json(url)
  df['data'] = pd.to_datetime(df['data'], dayfirst=True)
  df.set_index('data', inplace=True)
  return df

  
#Estes são exemplos de informações que podem ser consultados na base de dados do Banco Central
ipca = consulta_bc(433)
selic_meta = consulta_bc(432)

# %%
selic_meta
# Out:
#             valor
# data
# 1999-03-05   45.0
# 1999-03-06   45.0
# 1999-03-07   45.0
# 1999-03-08   45.0
# 1999-03-09   45.0
# ...           ...
# 2021-03-13    2.0
# 2021-03-14    2.0
# 2021-03-15    2.0
# 2021-03-16    2.0
# 2021-03-17    2.0
#
# [8049 rows x 1 columns]

# %%
type(selic_meta)
# Out:
# pandas.core.frame.DataFrame

# %%
selic_meta.plot()

# %%
Colunas=["Aporte Inicial", "Data", "Taxa","RendimentoAnual"]

# %%
df = pd.DataFrame(columns=Colunas)
df
# Out:
# Empty DataFrame
# Columns: [Aporte Inicial, Data, Taxa, RendimentoAnual]
# Index: []
